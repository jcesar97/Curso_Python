# %%
print('''De esta manera
nos ahorramos a nun 
pero no a \tuna ... no a la tabulacion''')
# Out:
# De esta manera
# nos ahorramos a nun
# pero no a 	una ... no a la tabulacion

# %%
strn = "En teoria sobre este tema donde salto de lineas es con \nson dos lineas"

# %%
strn
# Out:
# 'En teoria sobre este tema donde salto de lineas es con \nson dos lineas'

# %%
print(strn)
# Out:
# En teoria sobre este tema donde salto de lineas es con
# son dos lineas

# %%
strn + strn
# Out:
# 'En teoria sobre este tema donde salto de lineas es con \nson dos lineasEn teoria sobre este tema donde salto de lineas es con \nson dos lineas'

# %%
strn
# Out:
# 'En teoria sobre este tema donde salto de lineas es con \nson dos lineas'

# %%
print(strn+strn)
# Out:
# En teoria sobre este tema donde salto de lineas es con
# son dos lineasEn teoria sobre este tema donde salto de lineas es con
# son dos lineas

# %%
primero = 'Primera parte'
segundo = 'Segunda parte'

# %%
print("Fusion de la " + primero + " y la " + segundo)
# Out:
# Fusion de la Primera parte y la Segunda parte
