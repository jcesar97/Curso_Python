# %%
"Julio Cesar"
# Out:
# 'Julio Cesar'

# %%
strn = 'Julio Cesar estudia "Python"'

# %%
strn
# Out:
# 'Julio Cesar estudia "Python"'

# %%
"Hola 'Julio Cesar'"
# Out:
# "Hola 'Julio Cesar'"

# %%
type(strn)
# Out:
# str

# %%
print('Comillas simples')
# Out:
# Comillas simples

# %%
print("Comillas dobles")
# Out:
# Comillas dobles

# %%
print('Julio es "......."')
# Out:
# Julio es "......."

# %%
print("Este texto tiene /n una nueva linea")
# Out:
# Este texto tiene /n una nueva linea

# %%
print("Este texto tiene \nuna nueva linea")
# Out:
# Este texto tiene
# una nueva linea

# %%
print("Este texto tiene \tuna nueva linea'(tabulacion)'")
# Out:
# Este texto tiene 	una nueva linea'(tabulacion)'

# %%
print('C:\nombre\julio')
# Out:
# C:
# ombre\julio

# %%
print(r'C:\nombre\julio')
# Out:
# C:\nombre\julio
