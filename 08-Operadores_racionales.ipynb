# %%
3 == 2
# Out:
# False

# %%
3 == 3
# Out:
# True

# %%
5 != 4
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
3 > 4
# Out:
# False

# %%
3 > 1
# Out:
# True

# %%
2 < 7
# Out:
# True

# %%
2 < 1
# Out:
# False

# %%
7 >= 5
# Out:
# True

# %%
7 >= 8
# Out:
# False

# %%
num = 7
real = 8
var = 3

# %%
num > var
# Out:
# True

# %%
var < real
# Out:
# True

# %%
real != num
# Out:
# True

# %%
var * num == real
# Out:
# False
