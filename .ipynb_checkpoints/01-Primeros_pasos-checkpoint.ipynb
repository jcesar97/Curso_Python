# %%
##https://docs.python.org/3.9/tutorial/introduction.html#

# %%
3+2
# Out:
# 5

# %%
7-5
# Out:
# 2

# %%
4*9
# Out:
# 36

# %%
17/3
# Out:
# 5.666666666666667

# %%
12%6
# Out:
# 0

# %%
(55-5*5+5/5)
# Out:
# 31.0

# %%
#Comentario
var = 5

# %%
var
# Out:
# 5

# %%
var+5
var
# Out:
# 5

# %%
var+5
# Out:
# 10

# %%
var
# Out:
# 5

# %%
var=var+5

# %%
var
# Out:
# 10

# %%
hello = "Hola Mundo"

# %%
var = hello

# %%
var
# Out:
# 'Hola Mundo'

# %%
var=10

# %%
var
# Out:
# 10

# %%
var*var
# Out:
# 100

# %%
tax = 12.5 / 100
price = 100.50
price * tax
# Out:
# 12.5625

# %%
# El operador "_" toma el valor del ultimo valor impreso
