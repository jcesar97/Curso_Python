# %%
2 + 2 == 7
# Out:
# False

# %%
not True
# Out:
# False

# %%
not True == False
# Out:
# True

# %%
False and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
num = 10

# %%
num > 3 and num < 12
# Out:
# True

# %%
num > 3 or num < 9
# Out:
# True

# %%
palabra = 'Alvaro'

# %%
palabra == "Pepe" or palabra == "kuka" or palabra == "Maria"
# Out:
# False

# %%
palabra == "Pepe" or palabra == "kuka" or palabra == "Alvaro"
# Out:
# True

# %%
palabra[0] == 'B'
# Out:
# False
