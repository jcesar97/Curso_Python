# %%
profesor = "Julio César"

# %%
profesor[2]
# Out:
# 'l'

# %%
profesor[6]
# Out:
# 'C'

# %%
profesor[-3]
# Out:
# 's'

# %%
profesor[2:9]
# Out:
# 'lio Cés'

# %%
profesor[2:]+profesor[:2]
# Out:
# 'lio CésarJu'

# %%
len(profesor)
# Out:
# 11
