# %%
input()
# Out:
#  alvaro
# 'alvaro'

# %%
"Alvaro"
# Out:
# 'Alvaro'

# %%
dato = input()
# Out:
#  Hola Mundo

# %%
dato
# Out:
# 'Hola Mundo'

# %%
dato = input()
# Out:
#  5

# %%
dato
# Out:
# '5'

# %%
dato + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1964/1633295070.py in <module>
# ----> 1 dato + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
 dato = int(dato)

# %%
dato
# Out:
# 5

# %%
dato + 15
# Out:
# 20

# %%
dato = input()
# Out:
#  2.5

# %%
dato = float(dato)

# %%
dato
# Out:
# 2.5

# %%
dato + 2.5
# Out:
# 5.0

# %%
dato = float(input("Introdusca un valor decimal"))
# Out:
# Introdusca un valor decimal 7

# %%
dato
# Out:
# 7.0
